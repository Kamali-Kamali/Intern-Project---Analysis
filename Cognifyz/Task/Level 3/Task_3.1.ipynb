# %% [markdown]
# #**Task: Restaurant Reviews**
#
# ##Analyze the text reviews to identify the most common positive and negative keywords.
#
# ##Calculate the average length of reviews and explore if there is a relationship between review length and rating.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/drive/MyDrive/Task/Cognifyz/Dataset .csv")

# %%
df['Rating text'].unique()
# Out:
# array(['Excellent', 'Very Good', 'Good', 'Average', 'Not rated', 'Poor'],
#       dtype=object)

# %%
df['Rating text'].value_counts()
# Out:
# Rating text
# Average      3737
# Not rated    2148
# Good         2100
# Very Good    1079
# Excellent     301
# Poor          186
# Name: count, dtype: int64

# %%
sns.countplot(x='Rating text',data=df, palette='coolwarm')
plt.title('Most common Positive and Negative Reviews')
plt.show()
# Out:
# <ipython-input-55-acda6351ca77>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Rating text',data=df, palette='coolwarm')

# %%
lenth=len(df['Rating text'])
per=(df['Rating text'].value_counts()/lenth)*100
print("Average length of reviews")
per
# Out:
# Average length of reviews
# Rating text
# Average      39.126793
# Not rated    22.489792
# Good         21.987226
# Very Good    11.297246
# Excellent     3.151502
# Poor          1.947440
# Name: count, dtype: float64

# %%
sns.barplot(x=per.index,y=per)
plt.ylabel('Percentage')
plt.title('Average length of reviews')
plt.show()

# %%
sns.countplot(x='Aggregate rating',data=df, palette='coolwarm')
plt.xticks(rotation=90)
plt.title("Rating")
plt.show()
# Out:
# <ipython-input-67-0a5d9dfbe71f>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Aggregate rating',data=df, palette='coolwarm')
